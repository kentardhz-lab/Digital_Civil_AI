# %% [markdown]
# # Phase 1 – Digital Civil AI
# Basic data analysis of structural elements using Python.

# %%
df.isnull()
# Out:
#    Element  Length_m  Load_kN
# 0    False     False    False
# 1    False     False    False
# 2    False     False    False
# 3    False     False    False

# %%
df["Length_m"].mean()
# Out:
# np.float64(4.8999999999999995)

# %%
df["Length_m"] = df["Length_m"].fillna(df["Length_m"].mean())

# %%
df.isnull().sum()
# Out:
# Element     0
# Length_m    0
# Load_kN     0
# dtype: int64

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("../data/elements.csv")
df
# Out:
#   Element  Length_m  Load_kN
# 0    Beam       6.0       45
# 1  Column       3.2      120
# 2    Slab       5.5       80
# 3   Beam2       NaN      100

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4 entries, 0 to 3
# Data columns (total 3 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Element   4 non-null      object
#  1   Length_m  3 non-null      float64
#  2   Load_kN   4 non-null      int64
# dtypes: float64(1), int64(1), object(1)
# memory usage: 228.0+ bytes

# %%
df.describe()
# Out:
#        Length_m     Load_kN
# count  3.000000    4.000000
# mean   4.900000   86.250000
# std    1.493318   31.983068
# min    3.200000   45.000000
# 25%    4.350000   71.250000
# 50%    5.500000   90.000000
# 75%    5.750000  105.000000
# max    6.000000  120.000000

# %%
df["Load_per_meter"] = df["Load_kN"] / df["Length_m"]

# %%
df
# Out:
#   Element  Length_m  Load_kN  Load_per_meter
# 0    Beam       6.0       45        7.500000
# 1  Column       3.2      120       37.500000
# 2    Slab       5.5       80       14.545455
# 3   Beam2       4.9      100       20.408163

# %%
if (df["Load_per_meter"] > 50).any():
    print("WARNING: Unusually high load per meter detected")
else:
    print("Load per meter values are within normal range")
# Out:
# Load per meter values are within normal range

# %%
plt.figure(figsize=(6,4))
plt.bar(df["Element"], df["Load_per_meter"])
plt.title("Load per meter by structural element")
plt.ylabel("kN/m")
plt.xlabel("Element")
plt.show()

# %%
df[df["Load_per_meter"] > 50]
# Out:
# Empty DataFrame
# Columns: [Element, Length_m, Load_kN, Load_per_meter]
# Index: []

# %% [markdown]
# The dataset contains structural elements with length and applied load values.
